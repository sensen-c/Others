# %%
import pandas as pd

#dfb = pd.read_csv(r"C:\Users\sensenc\Desktop\domain_id.csv")
#dfa = pd.read_csv(r"C:\Users\sensenc\Desktop\domain_name.csv")
#df = pd.merge(dfa,dfb,left_on = 'id',right_on = 'domain_id',how='left')

df=pd.read_csv(r'C:\Users\sensenc\Desktop\domain_no5_102.csv')

categorylist = set(df.finding_sub_type.to_list())
print(categorylist)

files = pd.DataFrame(columns=df.columns)
for x in categorylist:
    dfsample = df[df.finding_sub_type == int(x)]
    file = pd.DataFrame(dfsample.sample(100))
    files = files.append(file)
files.to_csv('leo.csv')
# Out:
# {2, 3, 4, 6, 7, 9, 10, 12, 22, 32, 35, 36, 40, 45, 173, 54, 63, 198, 209, 84, 88, 217, 89, 93}

# %%
files = pd.DataFrame()
for x in categorylist:
    dfsample = df[df.finding_sub_type == int(x)]
    file = pd.DataFrame(dfsample.sample(100)
    #print(file)
    files = files.append(file)
files.to_csv('leo.csv')
# Out:
# (23, 9)
#                              domain         id_x         id_y    domain_id  \
# 6862                      delila.de  14459221898  16461598861  14459221898
# 7450                 malaikahair.de  14331440101  16461870698  14331440101
# 9315         echthaargrosshandel.de  14330426222  16462492127  14330426222
# 9419             salon-haarlekin.de  14333708255  16462526159  14333708255
# 12836           friseur-foerster.de  14385672918  16463823854  14385672918
# 39059                peruecken24.de  14332066128  16472369874  14332066128
# 39128         extensionsparadise.de  14468174290  16472379734  14468174290
# 40785                   remyhaar.eu  17107071247  16472829920  17107071247
# 40887                 hairdoshop.de  20342229212  16472884858  20342229212
# 43457          rapunzelofsweden.com  14338326353  16473553648  14338326353
# 49354               trendy-hairs.de  14388432396  16475132649  14388432396
# ...
